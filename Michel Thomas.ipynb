# %%
PLAYLISTS = [
    # German
    "id004325410",
    "id004325397",
    "id004325460",
    "id004325398",
    "id004325476",

    # French
    "id004325385",
    "id004325396",
    "id004325459",
    "id004325393",
    "id004325485",

    # Spanish
    "id004325462",
    "id004325417",
    "id004325477",
    "id004325424",
    "id004325381",
]

OUT_PATH="./output"

# %%
from ipython_secrets import get_secret

ELGGPERM_TOKEN = get_secret("ELGGPERM_TOKEN")
ASP_SESSION_ID = get_secret("ASP_SESSION_ID")

# %%
from scrapers.mthomas import get_playlist, scrape_playlist

# %%
for id in PLAYLISTS:
    playlist = get_playlist(id=id, elggperm_token=ELGGPERM_TOKEN, asp_session_id=ASP_SESSION_ID)
    scrape_playlist(pl=playlist, out_path=OUT_PATH)
# Out:
# Trying to resolve tracklist with ID id004325424...
# Getting tracklist Intermediate Spanish (140 tracks)
# 	Getting track 1/140 - 01.01 Intermediate Spanish.mp3...
# 		[EXISTS]
# 	Getting track 2/140 - 01.02 Intermediate Spanish.mp3...
# 		[EXISTS]
# 	Getting track 3/140 - 01.03 Intermediate Spanish.mp3...
# 		[EXISTS]
# 	Getting track 4/140 - 01.04 Intermediate Spanish.mp3...
# 		[EXISTS]
# 	Getting track 5/140 - 01.05 Intermediate Spanish.mp3...
# 		[EXISTS]
# 	Getting track 6/140 - 01.06 Intermediate Spanish.mp3...
# 		[EXISTS]
# 	Getting track 7/140 - 01.07 Intermediate Spanish.mp3...
# 		[EXISTS]
# 	Getting track 8/140 - 01.08 Intermediate Spanish.mp3...
# 		[EXISTS]
# 	Getting track 9/140 - 01.09 Intermediate Spanish.mp3...
# 		[EXISTS]
# 	Getting track 10/140 - 01.10 Intermediate Spanish.mp3...
# 		[EXISTS]
# 	Getting track 11/140 - 01.11 Intermediate Spanish.mp3...
# 		[EXISTS]
# 	Getting track 12/140 - 01.12 Intermediate Spanish.mp3...
# 		[EXISTS]
# ...
